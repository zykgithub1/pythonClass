# %% [markdown]
# # markdown display

# %% [markdown]
# ## second title

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# - first
#     - second
#         - third

# %%
import requests

# %%
r=requests.get("https://www.douban.com/game/25931998/comments?sort=score")

# %%
print(r.status_code)
# Out:
# 418

# %%
url="https://www.douban.com/game/25931998/comments?sort=score"
my_headers={"user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36"}
r=requests.get(url,headers=my_headers)

# %%
print(r.status_code)
# Out:
# 200

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" class="ua-windows ua-webkit">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta name="renderer" content="webkit">
#     <meta name="referrer" content="always">
#     <meta name="google-site-verification" content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" />
#     <title>关于赛博朋克2077 Cyberpunk 2077的评论(5346)</title>
#
#
#
# <script>
# ...

# %%
from lxml import etree

# %%
selector=etree.HTML(r.text)
selector.xpath("//div[@class='user-info']")
# Out:
# [<Element div at 0x7fae4b8e4fc0>,
#  <Element div at 0x7fae4b6c7d80>,
#  <Element div at 0x7fae4b6c7840>,
#  <Element div at 0x7fae4b6c7980>,
#  <Element div at 0x7fae4ba44300>,
#  <Element div at 0x7fae4b3dcd40>,
#  <Element div at 0x7fae4b3dcdc0>,
#  <Element div at 0x7fae4b3dc180>,
#  <Element div at 0x7fae4b3dca40>,
#  <Element div at 0x7fae4b75d6c0>,
#  <Element div at 0x7fae4b6d6880>,
#  <Element div at 0x7fae4b6d6e40>,
#  <Element div at 0x7fae4b6b1700>,
#  <Element div at 0x7fae4b3e6040>,
#  <Element div at 0x7fae4b3e6500>,
#  <Element div at 0x7fae4b3e6840>,
#  <Element div at 0x7fae4b3e6f40>,
#  <Element div at 0x7fae4b3e6140>,
#  <Element div at 0x7fae4b6dda80>,
#  <Element div at 0x7fae4b6dd380>]

# %%
username=selector.xpath('//div[@class="user-info"]/a/text()')
print(username)
len(username)
# Out:
# ['饮痴', 'Liew Enomis', 'Parker Tan', 'EzioAuditoreX', 'ICTS', 'Cris', '顾靳', 'yan', '暗涌', 'dd2', '今天也很烦心i', 'Tony', '毛多夫斯基', 'Darkness', 'dakongwz', '[已注销]', 'Lambda', '汶    汶', 'ZZ风起时', '杲杲']
# 20

# %%
star=selector.xpath("//div[@class='user-info']/span[2]/@class")
print(star)
len(star)
# Out:
# ['allstar50', 'allstar10', 'allstar10', 'allstar50', 'allstar20', 'allstar40', 'allstar30', 'allstar50', 'allstar10', 'allstar50', 'allstar20', 'allstar10', 'allstar50', 'allstar10', 'allstar10']
# 15

# %%
comment=selector.xpath("//span[@class='short']/text()")
print(comment)
len(comment)
# Out:
# ['今天班里的男生怎么都请病假了？', 'wdnmd室友玩这个破风扇响了一早上，以至于我下意识觉得回笼觉是在鞍山钢铁厂睡的', '除了我对2077无数次的游戏工业劳资政治批判还是要说一下。有一位群友不满我玩都不玩就喷2077是烂货实属不够客观让我玩了再说。我即刻拿来玩了一下(支线、结局全清)，结果发现果然烂的难以形容。顺带奉劝一下某些还觉得2077是LGBTQ Friendly的公益朋友即便不关心劳工问题也至少在性别政治和文化工业创作问题上带点脑子，这游戏性别内容那可真是反动至极了。', '玩家是平等的，主播不比普通玩家高贵', '把妓院翻译成绀碧大厦那条评论居然有800赞？！稍微玩了一丢剧情都知道是酒店！还有原文是紺碧プラザ，绀碧大厦完全是直译，云玩家和跟风党真是够了！跟风踩一脚显得很高贵是吗？', '除非达到大镖客2级别 否则你看我把不把这游戏往死里冲就完事了 菜还没做出来宣传得跟美国大选似的 宁配吗？ 不踏实做游戏整这些虚的当玩家是傻子？通关后感想：实力上等于1.5个育碧3A 多的0.5是剧情 美术层面上土得掉渣 如果认为多加灯管多搞点奇装异服和生殖器就是赛博朋克的话就别出来臊皮了', '你在等赛博朋克2077发售；他在等富坚义博重开连载；我在等EVA终上映：我们都有光明的未来', '到底什么样的人会觉得绀碧大厦是妓院，还得到这么多的赞？？', '那个打一星说主播不比普通玩家高贵的是睿智吗？主播等媒体提前游玩相当于宣传打广告，这不是很多游戏的惯例？另外，这游戏您买了吗，玩了吗？', '越来越多的迹象表明，这个游戏发售日期是在2077年。（捏🐮子模拟器）bug太多，7小时遇见两次影响游戏正常进行的bug。射击手感有些问题，剧情画面一流。  30小时一周目通关，野心太大，无奈游戏画了个大饼', '这是个RPG！RPG！RPG！没耐心看文本推剧情只想突突突的买了觉得无聊然后来骂来黑的是不是弱智？自己买之前不知道了解一下cdpr做的游戏都是什么类型什么风格的吗？', '怎么了？？你是放弃ps4的玩家了吗？？', 'CDPR在他们不太擅长的地方——开放世界、车辆系统等领域交出了一份中规中矩的答卷，但是在他们擅长的领域——讲故事、氛围感等方面做到了登峰造极。如果你喜欢GTA，那么他可能不是一款让你立刻着迷的游戏，而如果你喜欢巫师、大镖客，2077将会是一场最灿烂的烟火
# ...

# %%
temp=selector.xpath("//div[@class='user-info']")
print(temp[0])
# Out:
# <Element div at 0x7fae4b8e4fc0>

# %%
temp[1].xpath("./span[2]/@class")
# Out:
# []

# %%
for everyelement in temp:
    username=everyelement.xpath("./a/text()")
    star=everyelement.xpath("./span[2]/@class")
    if not star:
        star=[]
        star.append("allstar0")
    print(username,star)
# Out:
# ['饮痴'] ['allstar50']
# ['Liew Enomis'] ['allstar0']
# ['Parker Tan'] ['allstar10']
# ['EzioAuditoreX'] ['allstar10']
# ['ICTS'] ['allstar50']
# ['Cris'] ['allstar20']
# ['顾靳'] ['allstar0']
# ['yan'] ['allstar0']
# ['暗涌'] ['allstar40']
# ['dd2'] ['allstar30']
# ['今天也很烦心i'] ['allstar50']
# ['Tony'] ['allstar10']
# ['毛多夫斯基'] ['allstar50']
# ['Darkness'] ['allstar20']
# ['dakongwz'] ['allstar10']
# ['[已注销]'] ['allstar0']
# ['Lambda'] ['allstar50']
# ['汶    汶'] ['allstar0']
# ['ZZ风起时'] ['allstar10']
# ['杲杲'] ['allstar10']

# %%
temp=selector.xpath("//div[@class='info']")
for everyelement in temp:
    username=everyelement.xpath("./div/a/text()")
    star=everyelement.xpath("./div/span[2]/@class")
    if not star:
        star=[]
        star.append("allstar0")
    comment=everyelement.xpath("./p/span[@class='short']/text()")
    print(username,star,comment)
# Out:
# ['饮痴'] ['allstar50'] ['今天班里的男生怎么都请病假了？']
# ['Liew Enomis'] ['allstar0'] ['wdnmd室友玩这个破风扇响了一早上，以至于我下意识觉得回笼觉是在鞍山钢铁厂睡的']
# ['Parker Tan'] ['allstar10'] ['除了我对2077无数次的游戏工业劳资政治批判还是要说一下。有一位群友不满我玩都不玩就喷2077是烂货实属不够客观让我玩了再说。我即刻拿来玩了一下(支线、结局全清)，结果发现果然烂的难以形容。顺带奉劝一下某些还觉得2077是LGBTQ Friendly的公益朋友即便不关心劳工问题也至少在性别政治和文化工业创作问题上带点脑子，这游戏性别内容那可真是反动至极了。']
# ['EzioAuditoreX'] ['allstar10'] ['玩家是平等的，主播不比普通玩家高贵']
# ['ICTS'] ['allstar50'] ['把妓院翻译成绀碧大厦那条评论居然有800赞？！稍微玩了一丢剧情都知道是酒店！还有原文是紺碧プラザ，绀碧大厦完全是直译，云玩家和跟风党真是够了！跟风踩一脚显得很高贵是吗？']
# ['Cris'] ['allstar20'] ['除非达到大镖客2级别 否则你看我把不把这游戏往死里冲就完事了 菜还没做出来宣传得跟美国大选似的 宁配吗？ 不踏实做游戏整这些虚的当玩家是傻子？通关后感想：实力上等于1.5个育碧3A 多的0.5是剧情 美术层面上土得掉渣 如果认为多加灯管多搞点奇装异服和生殖器就是赛博朋克的话就别出来臊皮了']
# ['顾靳'] ['allstar0'] ['你在等赛博朋克2077发售；他在等富坚义博重开连载；我在等EVA终上映：我们都有光明的未来']
# ['yan'] ['allstar0'] ['到底什么样的人会觉得绀碧大厦是妓院，还得到这么多的赞？？']
# ['暗涌'] ['allstar40'] ['那个打一星说主播不比普通玩家高贵的是睿智吗？主播等媒体提前游玩相当于宣传打广告，这不是很多游戏的惯例？另外，这游戏您买了吗，玩了吗？']
# ...

# %%
temp=selector.xpath("//div[@class='info']")
with open("./game_short.txt","w+")as f:
    for everyelement in temp:
        username=everyelement.xpath("./div/a/text()")
        star=everyelement.xpath("./div/span[2]/@class")
        if not star:
            star=[]
            star.append("allstar0")
        comment=everyelement.xpath("./p/span[@class='short']/text()")
        game_short="{},{},{}".format(username,star,comment)
        f.write(game_short)

# %%
f=open("./game_short.txt","r")
