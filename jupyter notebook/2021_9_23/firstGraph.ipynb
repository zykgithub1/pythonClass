# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
midwest=pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/midwest_filter.csv")

# %%
midwest.head()
# Out:
#    PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022     14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018      5836   324.222222      5264       547
#
#    popamerindian  popasian  ...  percprof  poppovertyknown  percpovertyknown  \
# 0             98       249  ...  4.355859            63628         96.274777
# 1             19        48  ...  2.870315            10529         99.087145
# 2             35        16  ...  4.488572            14235         94.956974
# 3             46       150  ...  4.197800            30337         98.477569
# 4             14         5  ...  3.367680             4815         82.505140
#
# ...

# %%
midwest.shape
# Out:
# (332, 29)

# %%
midwest.columns
# Out:
# Index(['PID', 'county', 'state', 'area', 'poptotal', 'popdensity', 'popwhite',
#        'popblack', 'popamerindian', 'popasian', 'popother', 'percwhite',
#        'percblack', 'percamerindan', 'percasian', 'percother', 'popadults',
#        'perchsd', 'percollege', 'percprof', 'poppovertyknown',
#        'percpovertyknown', 'percbelowpoverty', 'percchildbelowpovert',
#        'percadultpoverty', 'percelderlypoverty', 'inmetro', 'category',
#        'dot_size'],
#       dtype='object')

# %%
plt.cm.tab10(6/2.7)
# Out:
# (0.09019607843137255, 0.7450980392156863, 0.8117647058823529, 1.0)

# %%
midwest["area"]
# Out:
# 0      0.052
# 1      0.014
# 2      0.022
# 3      0.017
# 4      0.018
#        ...
# 327    0.032
# 328    0.050
# 329    0.045
# 330    0.037
# 331    0.048
# Name: area, Length: 332, dtype: float64

# %%
midwest["poptotal"]
# Out:
# 0      66090
# 1      10626
# 2      14991
# 3      30806
# 4       5836
#        ...
# 327    75000
# 328    13772
# 329    46104
# 330    19385
# 331    73605
# Name: poptotal, Length: 332, dtype: int64

# %%
categories=np.unique(midwest.category)

# %%
categories
# Out:
# array(['AAR', 'AAU', 'AHR', 'ALR', 'ALU', 'HAR', 'HAU', 'HHR', 'HLR',
#        'HLU', 'LAR', 'LAU', 'LHR', 'LHU'], dtype=object)

# %%
#self atempt
plt.scatter(midwest.area,midwest.poptotal,c=plt.cm.tab10(3/2.7))
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
color1=plt.cm.tab10(7.1)

# %%
x1=np.array(np.random.randn(10))
type(x1)
# Out:
# numpy.ndarray

# %%
x11=np.random.randn(10)
x11
# Out:
# array([-1.40212919,  0.19211984, -1.43371134,  1.20119836,  0.27951546,
#         0.65334707,  0.44015346, -0.30103732,  0.30409423,  0.38461102])

# %%
x2=x1+x1**2-10

# %%
plt.scatter(x1,x2,c=np.array(color1).reshape(1,-1))

# %%
plt.figure(figsize=(20,8))
for i in range(len(categories)):
    plt.scatter(midwest[midwest["category"]==categories[i]]["area"],
               midwest[midwest["category"]==categories[i]]["poptotal"],
                s=20,label=categories[i],
               c=np.array(plt.cm.tab10(i/len(categories))).reshape(1,-1),
               )
plt.legend()

# %%
colors=[plt.cm.tab10(i/float(len(categories)-1)) for i in range(len(categories))]
colors
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765, 1.0),
#  (0.12156862745098039, 0.4666666666666667, 0.7058823529411765, 1.0),
#  (1.0, 0.4980392156862745, 0.054901960784313725, 1.0),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313, 1.0),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392, 1.0),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392, 1.0),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353, 1.0),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354, 1.0),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902, 1.0),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902, 1.0),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745, 1.0),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333, 1.0),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529, 1.0),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529, 1.0)]

# %%
midwest[midwest["category"]==categories[0]]["area"]
midwest.loc[midwest["category"]==categories[0],"area"]
# Out:
# 0      0.052
# 2      0.022
# 4      0.018
# 5      0.050
# 7      0.027
#        ...
# 327    0.032
# 328    0.050
# 329    0.045
# 330    0.037
# 331    0.048
# Name: area, Length: 186, dtype: float64

# %%
plt.figure(figsize=(10,8))

for i in range(len(categories)):
    plt.scatter(midwest[midwest["category"]==categories[i]]["area"],
                midwest[midwest["category"]==categories[i]]["poptotal"],
                c=np.array(colors[i]).reshape(1,-1),
                s=20
               )

# %%
plt.figure(figsize=(10,8))
for i in range(len(categories)):
    plt.scatter("area","poptotal",
               data=midwest[midwest.category==categories[i]],
               s=20,
                c=np.array(plt.cm.tab10(i/(len(categories)))).reshape(1,-1),
                label=categories[i]
               )
plt.legend(loc="upper right")

# %%
[*enumerate(categories)]
# Out:
# [(0, 'AAR'),
#  (1, 'AAU'),
#  (2, 'AHR'),
#  (3, 'ALR'),
#  (4, 'ALU'),
#  (5, 'HAR'),
#  (6, 'HAU'),
#  (7, 'HHR'),
#  (8, 'HLR'),
#  (9, 'HLU'),
#  (10, 'LAR'),
#  (11, 'LAU'),
#  (12, 'LHR'),
#  (13, 'LHU')]

# %%
plt.figure(figsize=(16,6))
for i,category in enumerate(categories):
    plt.scatter("area","poptotal",
               data=midwest.loc[midwest.category==category],
                s=20,c=np.array(plt.cm.tab20(i/(len(categories)))).reshape(1,-1),
                label=str(category)
               )
plt.legend()

# %%
s=midwest.loc[midwest.category==categories[0]]

# %%
v=midwest[midwest.category==categories[0]]

# %%
v == s
# Out:
#       PID  county  state  area  poptotal  popdensity  popwhite  popblack  \
# 0    True    True   True  True      True        True      True      True
# 2    True    True   True  True      True        True      True      True
# 4    True    True   True  True      True        True      True      True
# 5    True    True   True  True      True        True      True      True
# 7    True    True   True  True      True        True      True      True
# ..    ...     ...    ...   ...       ...         ...       ...       ...
# 327  True    True   True  True      True        True      True      True
# 328  True    True   True  True      True        True      True      True
# 329  True    True   True  True      True        True      True      True
# 330  True    True   True  True      True        True      True      True
# 331  True    True   True  True      True        True      True      True
#
#      popamerindian  popasian  ...  percprof  poppovertyknown  \
# ...

# %%
midwest.loc[midwest.area>0.1].county
# Out:
# 196    MARQUETTE
# Name: county, dtype: object

# %%
midwest.category.value_counts().index[0]
# Out:
# 'AAR'

# %%
midwest["c1"]=midwest.category.apply(lambda x:x[0])
midwest["c2"]=midwest.category.apply(lambda x:x[1])
midwest["c3"]=midwest.category.apply(lambda x:x[2])

# %%
midwest.head()
# Out:
#    PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022     14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018      5836   324.222222      5264       547
#
#    popamerindian  popasian  ...  percbelowpoverty  percchildbelowpovert  \
# 0             98       249  ...         13.151443             18.011717
# 1             19        48  ...         32.244278             45.826514
# 2             35        16  ...         12.068844             14.036061
# 3             46       150  ...          7.209019             11.179536
# 4             14         5  ...         13.520249             13.022889
#
#    percadultpoverty  percelderlypoverty  inmetro  category    dot_size  c1  \
# ...

# %%
midwest["c1"].value_counts()
# Out:
# A    248
# L     62
# H     22
# Name: c1, dtype: int64

# %%
midwest["c2"].value_counts()
# Out:
# A    249
# H     46
# L     37
# Name: c2, dtype: int64

# %%
midwest["c3"].value_counts()
# Out:
# R    279
# U     53
# Name: c3, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder as OE

# %%
data=midwest.copy()
data.head()
# Out:
#    PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022     14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018      5836   324.222222      5264       547
#
#    popamerindian  popasian  ...  percbelowpoverty  percchildbelowpovert  \
# 0             98       249  ...         13.151443             18.011717
# 1             19        48  ...         32.244278             45.826514
# 2             35        16  ...         12.068844             14.036061
# 3             46       150  ...          7.209019             11.179536
# 4             14         5  ...         13.520249             13.022889
#
#    percadultpoverty  percelderlypoverty  inmetro  category    dot_size  c1  \
# ...

# %%
data.iloc[:,-3:]
# Out:
#     c1 c2 c3
# 0    A  A  R
# 1    L  H  R
# 2    A  A  R
# 3    A  L  U
# 4    A  A  R
# ..  .. .. ..
# 327  A  A  R
# 328  A  A  R
# 329  A  A  R
# 330  A  A  R
# 331  A  A  R
#
# [332 rows x 3 columns]

# %%
data.iloc[:,-3:]=OE().fit_transform(data.iloc[:,-3:])

# %%
data.iloc[:,-3:]
# Out:
#       c1   c2   c3
# 0    0.0  0.0  0.0
# 1    2.0  1.0  0.0
# 2    0.0  0.0  0.0
# 3    0.0  2.0  1.0
# 4    0.0  0.0  0.0
# ..   ...  ...  ...
# 327  0.0  0.0  0.0
# 328  0.0  0.0  0.0
# 329  0.0  0.0  0.0
# 330  0.0  0.0  0.0
# 331  0.0  0.0  0.0
#
# [332 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PID                   332 non-null    int64
#  1   county                332 non-null    object
#  2   state                 332 non-null    object
#  3   area                  332 non-null    float64
#  4   poptotal              332 non-null    int64
#  5   popdensity            332 non-null    float64
#  6   popwhite              332 non-null    int64
#  7   popblack              332 non-null    int64
#  8   popamerindian         332 non-null    int64
#  9   popasian              332 non-null    int64
#  10  popother              332 non-null    int64
#  11  percwhite             332 non-null    float64
#  12  percblack             332 non-null    float64
#  13  percamerindan         332 non-null    float64
#  14  percasian             332 non-null    float64
# ...

# %%
data.columns
# Out:
# Index(['PID', 'county', 'state', 'area', 'poptotal', 'popdensity', 'popwhite',
#        'popblack', 'popamerindian', 'popasian', 'popother', 'percwhite',
#        'percblack', 'percamerindan', 'percasian', 'percother', 'popadults',
#        'perchsd', 'percollege', 'percprof', 'poppovertyknown',
#        'percpovertyknown', 'percbelowpoverty', 'percchildbelowpovert',
#        'percadultpoverty', 'percelderlypoverty', 'inmetro', 'category',
#        'dot_size', 'c1', 'c2', 'c3'],
#       dtype='object')

# %%
data.loc[:,data.dtypes.values!='O'].shape
# Out:
# (332, 29)

# %%
data.shape
# Out:
# (332, 32)

# %%
data=data.loc[:,data.dtypes.values!='O']

# %%
data.shape
# Out:
# (332, 29)

# %%
for i in range(data.loc[:,data.dtypes.values=='int64'].shape[1]):
    data.loc[i,data.dtypes.values=="int64"]=data.loc[i,data.dtypes.values=="int64"].apply(lambda x:float(x))

# %%
for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        data.iloc[i,j]=float(data.iloc[i,j])

# %%
data.dtypes.values
# Out:
# array([dtype('int64'), dtype('float64'), dtype('int64'), dtype('float64'),
#        dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'),
#        dtype('int64'), dtype('float64'), dtype('float64'),
#        dtype('float64'), dtype('float64'), dtype('float64'),
#        dtype('int64'), dtype('float64'), dtype('float64'),
#        dtype('float64'), dtype('int64'), dtype('float64'),
#        dtype('float64'), dtype('float64'), dtype('float64'),
#        dtype('float64'), dtype('int64'), dtype('float64'),
#        dtype('float64'), dtype('float64'), dtype('float64')], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PID                   332 non-null    int64
#  1   area                  332 non-null    float64
#  2   poptotal              332 non-null    int64
#  3   popdensity            332 non-null    float64
#  4   popwhite              332 non-null    int64
#  5   popblack              332 non-null    int64
#  6   popamerindian         332 non-null    int64
#  7   popasian              332 non-null    int64
#  8   popother              332 non-null    int64
#  9   percwhite             332 non-null    float64
#  10  percblack             332 non-null    float64
#  11  percamerindan         332 non-null    float64
#  12  percasian             332 non-null    float64
#  13  percother             332 non-null    float64
#  14  popadults             332 non-null    int64
# ...

# %%
X=data.iloc[:,1:-3]

# %%
X
# Out:
#       area  poptotal   popdensity  popwhite  popblack  popamerindian  \
# 0    0.052     66090  1270.961540     63917      1702             98
# 1    0.014     10626   759.000000      7054      3496             19
# 2    0.022     14991   681.409091     14477       429             35
# 3    0.017     30806  1812.117650     29344       127             46
# 4    0.018      5836   324.222222      5264       547             14
# ..     ...       ...          ...       ...       ...            ...
# 327  0.032     75000  2343.750000     72747       454            201
# 328  0.050     13772   275.440000     13585        25            122
# 329  0.045     46104  1024.533330     45695        22            125
# 330  0.037     19385   523.918919     19094        29             70
# 331  0.048     73605  1533.437500     72157        90            481
#
#      popasian  popother  percwhite  percblack  ...  percollege  percprof  \
# ...

# %%
y=data.iloc[:,-3:]

# %%
y
# Out:
#       c1   c2   c3
# 0    0.0  0.0  0.0
# 1    2.0  1.0  0.0
# 2    0.0  0.0  0.0
# 3    0.0  2.0  1.0
# 4    0.0  0.0  0.0
# ..   ...  ...  ...
# 327  0.0  0.0  0.0
# 328  0.0  0.0  0.0
# 329  0.0  0.0  0.0
# 330  0.0  0.0  0.0
# 331  0.0  0.0  0.0
#
# [332 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,random_state=1996,test_size=0.3)

# %%
for i in [x_train,x_test,y_train,y_test]:
    i.index=range(i.shape[0])

# %%
x_train.shape
# Out:
# (232, 25)

# %%
x_train.iloc[:,[*range(23),-1]].shape
# Out:
# (232, 24)

# %%
x_train.head()
# Out:
#     area  poptotal   popdensity  popwhite  popblack  popamerindian  popasian  \
# 0  0.024     40307  1679.458330     39743       330             67       142
# 1  0.032     32653  1020.406250     32388        64             54       102
# 2  0.044     20893   474.840909     20148       599             40        35
# 3  0.029     16522   569.724138     16397        41             37        35
# 4  0.052     35909   690.557692     34929       172             95       633
#
#    popother  percwhite  percblack  ...  percollege  percprof  poppovertyknown  \
# 0        25  98.600739   0.818716  ...   14.700020  3.705296            39745
# 1        45  99.188436   0.196000  ...   22.805218  4.973374            31693
# 2        71  96.434212   2.866989  ...   13.602994  2.986901            19452
# 3        12  99.243433   0.248154  ...   15.928740  3.248625            16152
# 4        80  97.270879   0.478989  ...   26.287016  7.506960            32837
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler().fit(x_train.iloc[:,[*range(23),-1]])

# %%
x_train_=x_train.copy()
x_test_=x_test.copy()

# %%
x_train_.iloc[:,[*range(23),-1]]=ss.fit_transform(x_train.iloc[:,[*range(23),-1]])
x_test_.iloc[:,[*range(23),-1]]=ss.fit_transform(x_test.iloc[:,[*range(23),-1]])

# %%
# Out:
#          area  poptotal  popdensity  popwhite  popblack  popamerindian  \
# 0   -0.618053  0.558991    0.929536  0.596516 -0.111834      -0.257657
# 1   -0.054087  0.122053   -0.014465  0.160377 -0.405190      -0.297652
# 2    0.791861 -0.549282   -0.795912 -0.565435  0.184831      -0.340723
# 3   -0.265574 -0.798806   -0.660005 -0.787864 -0.430555      -0.349952
# 4    1.355827  0.307926   -0.486927  0.311054 -0.286083      -0.171515
# ..        ...       ...         ...       ...       ...            ...
# 227  1.003348 -1.390734   -1.288538 -1.397214 -0.474669      -0.386870
# 228 -0.688548 -0.569491   -0.196957 -0.553694 -0.369899      -0.331493
# 229  1.708305 -0.662998   -1.001090 -0.644955 -0.473566      -0.343799
# 230 -0.477061  0.348286    0.541150  0.402196 -0.439378      -0.371488
# 231 -0.618053 -0.157898    0.180053 -0.124789 -0.405190      -0.313034
#
#      popasian  popother  percwhite  percblack  ...  percollege  percprof  \
# ...
