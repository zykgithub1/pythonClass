# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("iris")

# %%
df.columns=["花萼长","花萼宽","花瓣长","花瓣宽","species"]

# %%
df.head()
# Out:
#    花萼长  花萼宽  花瓣长  花瓣宽 species
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
plt.figure(figsize=(10,8),dpi=80)
plt.rcParams['font.sans-serif']=["SimHei"]
sns.pairplot(df,kind="reg",hue="species")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10952/478795449.py in <module>
#       1 plt.figure(figsize=(10,8),dpi=80)
#       2 plt.rcParams['font.sans-serif']=["SimHei"]
# ----> 3 sns.pairplot(df,kind="reg",hue="species",fontsize=25)
#
# d:\codeinstalls\python\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: pairplot() got an unexpected keyword argument 'fontsize'

# %%
plt.figure(figsize=(10,8),dpi=80)
plt.rcParams['font.sans-serif']=["SimHei"]
sns.pairplot(df,kind="scatter",hue="species",plot_kws=dict(s=40,edgecolor="white",linewidth=1))

# %%
plt.figure(figsize=(10,8),dpi=80)
plt.rcParams['font.sans-serif']=["SimHei"]
sns.pairplot(df,kind="reg",hue="species")
